# %% [markdown]
# # Life Expectancy
#
# Analysing the Life expectancy at birth, total (years). Data source – [World Bank](https://data.worldbank.org/indicator/SP.DYN.LE00.IN) (License : CC BY-4.0).

# %%
# %matplotlib inline

import pandas as pd
import numpy as np

# %%
ls data/life_expectancy/
# Out:
# API_SP.DYN.LE00.IN_DS2_en_csv_v2.csv

# %%
# !head data/life_expectancy/API_SP.DYN.LE00.IN_DS2_en_csv_v2.csv
# Out:
# ﻿"Data Source","World Development Indicators",
#
# "Last Updated Date","2018-03-01",
#
# "Country Name","Country Code","Indicator Name","Indicator Code","1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017",
# ...

# %%
df = pd.read_csv("data/life_expectancy/API_SP.DYN.LE00.IN_DS2_en_csv_v2.csv", header=2, index_col=[0,1,2, 3])
df
# Out:
#                                                                                                                              1960  \
# Country Name                                       Country Code Indicator Name                          Indicator Code
# Aruba                                              ABW          Life expectancy at birth, total (years) SP.DYN.LE00.IN  65.569366
# Afghanistan                                        AFG          Life expectancy at birth, total (years) SP.DYN.LE00.IN  32.337561
# Angola                                             AGO          Life expectancy at birth, total (years) SP.DYN.LE00.IN  33.226024
# Albania                                            ALB          Life expectancy at birth, total (years) SP.DYN.LE00.IN  62.254366
# Andorra                                            AND          Life expectancy at birth, total (years) SP.DYN.LE00.IN        NaN
# ...

# %%
life_expectancy = df.groupby(level=0).first().transpose()
life_expectancy
# Out:
# Country Name  Afghanistan    Albania    Algeria  American Samoa  Andorra  \
# 1960            32.337561  62.254366  46.135122             NaN      NaN
# 1961            32.786976  63.273463  46.590317             NaN      NaN
# 1962            33.228927  64.162854  47.045000             NaN      NaN
# 1963            33.666902  64.887098  47.496195             NaN      NaN
# 1964            34.101902  65.438195  47.941902             NaN      NaN
# 1965            34.534902  65.827390  48.376098             NaN      NaN
# 1966            34.966927  66.089317  48.790805             NaN      NaN
# 1967            35.398927  66.287220  49.187512             NaN      NaN
# 1968            35.832415  66.474951  49.572707             NaN      NaN
# 1969            36.269390  66.681610  49.955902             NaN      NaN
# 1970            36.712829  66.932585  50.343634             NaN      NaN
# 1971            37.161756  67.238878  50.743927             NaN      NaN
# ...

# %%
list(life_expectancy.columns)
# Out:
# ['Afghanistan',
#  'Albania',
#  'Algeria',
#  'American Samoa',
#  'Andorra',
#  'Angola',
#  'Antigua and Barbuda',
#  'Arab World',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas, The',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bermuda',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'British Virgin Islands',
#  'Brunei Darussalam',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cabo Verde',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Caribbean small states',
#  'Cayman Islands',
#  'Central African Republic',
#  'Central Europe and the Baltics',
#  'Chad',
#  'Channel Islands',
#  'Chile',
#  'China',
#  'Colombia',
#  'Comoros',
#  'Congo, Dem. Rep.',
#  'Congo, Rep.',
#  'Costa Rica',
#  "Cote d'Ivoire",
#  'Croatia',
#  'Cuba',
#  'Curacao',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'Djibouti',
# ...

# %%
#life_expectancy.ix[:,['United Sates', 'United Kingdom']]#.plot()
life_expectancy_subset = life_expectancy[['United States', 'Germany', 'Russian Federation', 'China', 'South Africa']]
life_expectancy_subset.tail(10)
# Out:
# Country Name  United States    Germany  Russian Federation      China  \
# 2009              78.390244  79.836585           68.684634  75.063439
# 2010              78.541463  79.987805           68.841220  75.266098
# 2011              78.641463  80.436585           69.683902  75.453829
# 2012              78.741463  80.539024           70.072195  75.628049
# 2013              78.741463  80.490244           70.578780  75.795171
# 2014              78.741463  81.090244           70.743659  75.957195
# 2015              78.741463  81.090244           70.908537  76.117098
# 2016                    NaN        NaN                 NaN        NaN
# 2017                    NaN        NaN                 NaN        NaN
# Unnamed: 62             NaN        NaN                 NaN        NaN
#
# Country Name  South Africa
# 2009             54.683463
# 2010             55.869610
# 2011             57.181073
# 2012             58.520415
# 2013             59.800073
# 2014             60.954780
# ...

# %%
life_expectancy_subset.plot()
